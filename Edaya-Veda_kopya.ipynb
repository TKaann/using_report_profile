# %%
import pandas as pd

# %%
df = pd.read_excel('cars.xls')

# %%
# !pip install pandas_profiling

#pip program kuruyor - extra ısımızı kolaylastıran #unlem koymak !lınux arayuzune gıdıyor phytondan cıkıyor
#bılgısayarın kendısıne progrem kurmus oluyoruz
#head vs eda'da kullandıklarımızı tek satıra ındırıyor bu onu saglıyor
#! ünlem bu programdan cıkıp lınux sheelden kuruyor programı

#pandas dan kurmak ıcın
#conda install -c conda-forge pandas-profiling=3.2.0
# Out:
# ...
#      ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#      - -------------------------------------- 10.2/262.6 kB ? eta -:--:--
#      ----- ------------------------------- 41.0/262.6 kB 495.5 kB/s eta 0:00:01
#      ------------ ------------------------ 92.2/262.6 kB 751.6 kB/s eta 0:00:01
#      --------------------- -------------- 153.6/262.6 kB 838.4 kB/s eta 0:00:01
#      ---------------------------------- --- 235.5/262.6 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 262.6/262.6 kB 1.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#      ------------------------------ ------- 245.8/309.8 kB 5.0 MB/s eta 0:00:01
#      -------------------------------- ----- 266.2/309.8 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 309.8/309.8 kB 2.4 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade pip

# %%
# %pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# ...
#      - 0 bytes ? 0:00:00
#      - 10.3 kB ? 0:00:00
#      \ 38.9 kB 594.9 kB/s 0:00:00
#      \ 95.1 kB 853.7 kB/s 0:00:00
#      | 203.0 kB 1.1 MB/s 0:00:00
#      | 222.2 kB 940.9 kB/s 0:00:00
#      / 420.5 kB 1.5 MB/s 0:00:00
#      / 458.4 kB 1.4 MB/s 0:00:00
#      - 626.2 kB 1.7 MB/s 0:00:00
#      - 763.3 kB 1.8 MB/s 0:00:00
#      \ 900.3 kB 1.9 MB/s 0:00:00
#      \ 1.1 MB 2.1 MB/s 0:00:00
#      | 1.2 MB 2.1 MB/s 0:00:00
#      / 1.3 MB 2.2 MB/s 0:00:00
#      / 1.5 MB 2.2 MB/s 0:00:00
#      - 1.6 MB 2.3 MB/s 0:00:00
#      - 1.8 MB 2.4 MB/s 0:00:00
#      \ 1.9 MB 2.4 MB/s 0:00:00
#      \ 2.1 MB 2.4 MB/s 0:00:00
#      | 2.2 MB 2.5 MB/s 0:00:00
#      | 2.3 MB 2.5 MB/s 0:00:00
#      / 2.5 MB 2.5 MB/s 0:00:00
#      / 2.6 MB 2.6 MB/s 0:00:01
#      - 2.8 MB 2.6 MB/s 0:00:01
#      - 2.9 MB 2.6 MB/s 0:00:01
#      \ 3.0 MB 2.6 MB/s 0:00:01
#      | 3.2 MB 2.6 MB/s 0:00:01
#      | 3.3 MB 2.7 MB/s 0:00:01
#      / 3.5 MB 2.6 MB/s 0:00:01
#      / 3.6 MB 2.7 MB/s 0:00:01
# ...

# %%
# !pip install markupsafe==2.0.1
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for markupsafe: filename=MarkupSafe-2.0.1-py3-none-any.whl size=9767 sha256=6afee7fdfeaef2d77f713b0efc6db04d1479772ea8e3e79a1afe0639b74ed818
#   Stored in directory: c:\users\tkaan\appdata\local\pip\cache\wheels\ea\18\79\6266ea508b8164a77b95aa19534c77eb805f2878612c37efca
# Successfully built markupsafe
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.1
#     Uninstalling MarkupSafe-2.1.1:
#       Successfully uninstalled MarkupSafe-2.1.1
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires markupsafe~=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# ...

# %%
pip install ipywidgets
# Out:
# ...
#
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
